# %%
# !apt-get update && apt-get install -y git-lfs
# !git lfs install
# Out:
# Hit:1 http://deb.debian.org/debian bullseye InRelease
# Hit:2 http://deb.debian.org/debian-security bullseye-security InRelease
# Hit:3 http://deb.debian.org/debian bullseye-updates InRelease
#
#
#
#
# git-lfs is already the newest version (2.13.2-1+deb11u1).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# Git LFS initialized.

# %%
# 克隆代码仓库
# !git clone https://github.com/jingyaogong/minimind-v
# %cd minimind-v
# Out:
# Cloning into 'minimind-v'...
# remote: Enumerating objects: 527, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 527 (delta 91), reused 92 (delta 70), pack-reused 382 (from 1)
# Receiving objects: 100% (527/527), 21.87 MiB | 2.35 MiB/s, done.
# Resolving deltas: 100% (292/292), done.
# Updating files: 100% (36/36), done.
# /datasets/_deepnote_work/minimind-v

# %%
# !mkdir out
# !mkdir /work/minimind-v/model/vision_model/clip-vit-base-patch16
# !git clone https://huggingface.co/jingyaogong/MiniMind2-V
# !git clone https://www.modelscope.cn/models/openai-mirror/clip-vit-base-patch16 /work/minimind-v/model/vision_model/clip-vit-base-patch16
# !wget -O out/lm_512.pth \
    https://huggingface.co/jingyaogong/MiniMind2-V-PyTorch/resolve/main/lm_512.pth
# Out:
# Cloning into 'MiniMind2-V'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 97 (delta 27), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (97/97), 271.97 KiB | 4.00 KiB/s, done.
# Checking connectivity: 97, done.
# Updating files: 100% (27/27), done.
# Filtering content: 100% (15/15), 206.82 MiB | 13.36 MiB/s, done.
# Cloning into '/work/minimind-v/model/vision_model/clip-vit-base-patch16'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 20 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (20/20), 1.08 MiB | 819.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (12/12), done.
# Filtering content: 100% (2/2), 1.11 GiB | 19.83 MiB/s, done.
# ...

# %%
# !pip install uv
# !uv venv mnm --python 3.10.16
# !source mnm/bin/activate
# !uv pip install gradio==5.0.1
# !grep -v "gradio" /work/minimind-v/requirements.txt > /tmp/requirements_no_gradio.txt
# !uv pip install -r /tmp/requirements_no_gradio.txt
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Using CPython 3.10.16
# Creating virtual environment at: mnm
# ? A virtual environment already exists at `mnm`. Do you want to replace it? [y/n] › yes
#
# hint: Use the `--clear` flag or set `UV_VENV_CLEAR=1` to skip this prompt
# Using Python 3.11.10 environment at: /root/venv
# Audited 1 package in 18ms
# Using Python 3.11.10 environment at: /root/venv
# Audited 30 packages in 29ms

# %%
# !python /work/minimind-v/scripts/web_demo_vlm.py
# Out:
# VLM参数量：104.622 百万
# * Running on local URL:  http://0.0.0.0:8080
#
# To create a public link, set `share=True` in `launch()`.
# ^C
# Keyboard interruption in main thread... closing server.

# %%
# 修改/work/minimind-v/scripts/web_demo_vlm.py              中的路径：../
# 修改/work/minimind-v/MiniMind2-V/model_minimind.py        中204行注释掉attn_mask=attn_mask,
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8080
#
# ^C
#   Stopping...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4c9dfb1e-ebe3-49db-b3a3-2fe77ce11687' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
