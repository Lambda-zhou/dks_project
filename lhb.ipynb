# %%
# !git clone https://github.com/Lambda-zhou/lhb_streamlit.git
# %cd lhb_streamlit
# !pip install -r requirements.txt
# Out:
# Cloning into 'lhb_streamlit'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 56 (delta 27), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 39.37 KiB | 19.00 KiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Updating files: 100% (15/15), done.
# /datasets/_deepnote_work/lhb_streamlit
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 95.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 53.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 203.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 83.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 43.1 MB/s eta 0:00:00
# ...

# %%
import sys
import os
# %cd lhb_streamlit/
# !pip install -r requirements.txt
# !pip install xlsxwriter==3.2.9
current_path = os.getcwd()  # 获取当前路径
sys.path.append(current_path)
# Out:
# /datasets/_deepnote_work/lhb_streamlit
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 226.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 61.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 229.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 39.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 210.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 185.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 87.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 47.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 249.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 258.7 MB/s eta 0:00:00
# ...

# %%
from ths_hot import concept_count, code_draw, get_merged_stock_data, main
from k_line import draw_kline
from api_search_draw import api_search_code_draw, api_search_name_draw
from db_search_draw import database_search_name_draw, database_search_code_draw
from find_lhs import find_lhb, search_in_lh, stock_risk
from flush_db import flush_database
from db_connect import db_connect
import datetime


def run_time():
    print(((datetime.datetime.utcnow() + datetime.timedelta(hours=8)).strftime("%Y-%m-%d")))
 
run_time()
result = main()
# result
# result[result['price'] <=10 ]
# result[(result['price'] <=10)]
# Out:
# 提取到68只股票代码
# <class 'pandas.core.frame.DataFrame'>

# %%
import os
import pandas as pd
import datetime

output_folder = 'output'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
file_path = os.path.join(output_folder, (datetime.datetime.utcnow() + datetime.timedelta(hours=8)).strftime("%Y-%m-%d") + '同花顺热榜.csv')
result.to_csv(file_path, header=True, index=False)

# %%
cc = concept_count(result)
cc = cc[cc['count'] >= 2]
cc.to_csv(file_path, mode='a', header=True, index=False)
cc
# Out:
#      concept  count                         stocks
# 61       页岩气      6  神开股份、山东墨龙、石化机械、石化油服、准油股份、贝肯能源
# 43      物业管理      3                 合肥城建、天保基建、云南城投
# 32      旅游概念      3                 盈新发展、茂化实华、珠江钢琴
# 23       天然气      3                  山东墨龙、石化油服、惠博普
# 17      国企改革      3                 黄河旋风、大有能源、三峡新材
# 39        流感      2                       广济药业、哈三联
# 36        染料      2                      蓝丰生化、世龙实业
# 44      特色小镇      2                      光明地产、云南城投
# 30     新型城镇化      2                      中化岩土、武汉控股
# 47       碳中和      2                      华塑控股、茂化实华
# 48      租售同权      2                      合肥城建、首开股份
# 26      工业母机      2                      华塑控股、沈阳机床
# 21      培育钻石      2                      黄河旋风、楚江新材
# 15       可燃冰      2                      神开股份、石化机械
# 2       一带一路      2                      建设机械、海鸥住工
# 3     上海国企改革      2                      上实发展、光明地产
# 60    雅下水电概念      2                      山河智能、北新路桥
# ...

# %%
import adata
df = adata.sentiment.hot.hot_concept_20_ths().loc[:, ['concept_name','concept_code','change_pct','hot_tag']]
df
# Out:
#    concept_name concept_code  change_pct   hot_tag
# 0           可燃冰       885748      4.0643    5天3次上榜
# 1          国企改革       886021      0.1224       NaN
# 2         可控核聚变       886065      0.1969   连续18天上榜
# 3           创新药       886015      0.1720  连续105天上榜
# 4    股权转让(并购重组)       885739     -0.0479      首次上榜
# 5          黄金概念       885530     -1.9763   连续33天上榜
# 6          存储芯片       886042     -0.6380   连续24天上榜
# 7         人形机器人       886069     -0.4925  连续235天上榜
# 8            流感       885879      0.8380       NaN
# 9          培育钻石       885937     -0.2076   10天9次上榜
# 10   共封装光学(CPO)       886033     -0.3650   连续71天上榜
# 11         ST板块       885699      1.0323   连续31天上榜
# 12          页岩气       885372      2.2872       NaN
# 13        机器人概念       885517     -0.3266   连续70天上榜
# 14         海工装备       885426      0.4603    5天3次上榜
# 15         固态电池       886032     -0.9786   连续33天上榜
# 16         芯片概念       885756     -0.4579   连续58天上榜
# ...

# %%
# %%bash
# pwd
# ls
# Out:
# /datasets/_deepnote_work/lhb_streamlit
# api_search_draw.py
# bash.sh
# db_connect.py
# db_search_draw.py
# find_lhs.py
# flush_db.py
# k_line.py
# lhb_streamlitpro.py
# lhb_streamlit.py
# python文件介绍
# README.md
# requirements.txt
# streamlit_explan.py
# ths_hot.py
# trade_day.py

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=53411bf0-f0fd-4c7d-a7b5-0b01c8cdbc2d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
